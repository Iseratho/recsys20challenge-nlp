# %%
from google.colab import auth
auth.authenticate_user()

# %%
# !gcloud config set project lively-tensor-284509
# Out:
# Updated property [core/project].
#
#
# To take a quick anonymous survey, run:
#   $ gcloud survey

# %%
# !gsutil mv gs://nlp_recsys2020/recsys2020_data/user_sampled_embeddings.parquet/user_sampled_embeddings.parquet  gs://nlp_recsys2020/new.parquet
# Out:
# Copying gs://nlp_recsys2020/recsys2020_data/user_sampled_embeddings.parquet/user_sampled_embeddings.parquet/_common_metadata [Content-Type=application/octet-stream]...
# Removing gs://nlp_recsys2020/recsys2020_data/user_sampled_embeddings.parquet/user_sampled_embeddings.parquet/_common_metadata...
# Copying gs://nlp_recsys2020/recsys2020_data/user_sampled_embeddings.parquet/user_sampled_embeddings.parquet/_metadata [Content-Type=application/octet-stream]...
# Removing gs://nlp_recsys2020/recsys2020_data/user_sampled_embeddings.parquet/user_sampled_embeddings.parquet/_metadata...
# Copying gs://nlp_recsys2020/recsys2020_data/user_sampled_embeddings.parquet/user_sampled_embeddings.parquet/part.0.parquet [Content-Type=application/octet-stream]...
# Removing gs://nlp_recsys2020/recsys2020_data/user_sampled_embeddings.parquet/user_sampled_embeddings.parquet/part.0.parquet...
# ...

# %%
# !gsutil -m rm -r gs://nlp_recsys2020/recsys2020_data/user_sampled_embeddings.parquet
# Out:
# Removing gs://nlp_recsys2020/recsys2020_data/user_sampled_embeddings.parquet/_common_metadata#1595756009402155...
# Removing gs://nlp_recsys2020/recsys2020_data/user_sampled_embeddings.parquet/_metadata#1595756010960630...
# Removing gs://nlp_recsys2020/recsys2020_data/user_sampled_embeddings.parquet/part.0.parquet#1595755895103804...
# Removing gs://nlp_recsys2020/recsys2020_data/user_sampled_embeddings.parquet/part.1.parquet#1595755961144958...
# Removing gs://nlp_recsys2020/recsys2020_data/user_sampled_embeddings.parquet/part.10.parquet#1595755928273638...
# Removing gs://nlp_recsys2020/recsys2020_data/user_sampled_embeddings.parquet/part.100.parquet#1595755908008044...
# Removing gs://nlp_recsys2020/recsys2020_data/user_sampled_embeddings.parquet/part.101.parquet#1595755956158502...
# Removing gs://nlp_recsys2020/recsys2020_data/user_sampled_embeddings.parquet/part.102.parquet#1595755952063185...
# ...

# %%
# !gsutil -m mv gs://nlp_recsys2020/new.parquet gs://nlp_recsys2020/recsys2020_data/user_sampled_embeddings.parquet
# Out:
# Copying gs://nlp_recsys2020/new.parquet/_common_metadata [Content-Type=application/octet-stream]...
# Copying gs://nlp_recsys2020/new.parquet/part.0.parquet [Content-Type=application/octet-stream]...
# Copying gs://nlp_recsys2020/new.parquet/_metadata [Content-Type=application/octet-stream]...
# Copying gs://nlp_recsys2020/new.parquet/part.1.parquet [Content-Type=application/octet-stream]...
# Copying gs://nlp_recsys2020/new.parquet/part.10.parquet [Content-Type=application/octet-stream]...
# Copying gs://nlp_recsys2020/new.parquet/part.101.parquet [Content-Type=application/octet-stream]...
# Copying gs://nlp_recsys2020/new.parquet/part.100.parquet [Content-Type=application/octet-stream]...
# Copying gs://nlp_recsys2020/new.parquet/part.102.parquet [Content-Type=application/octet-stream]...
# Copying gs://nlp_recsys2020/new.parquet/part.103.parquet [Content-Type=application/octet-stream]...
# ...
